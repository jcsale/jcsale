# %% [markdown]
# <a href="https://colab.research.google.com/github/jcsale/jcsale/blob/main/Perclos_Feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing tools

# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/driver_drowsiness_detection_modified.zip
# !unzip -qo driver_drowsiness_detection_modified.zip
# Out:
# --2022-01-27 13:09:48--  https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/driver_drowsiness_detection_modified.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.158.107
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.158.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127436131 (122M) [application/x-zip-compressed]
# Saving to: ‘driver_drowsiness_detection_modified.zip’
#
# driver_drowsiness_d 100%[===================>] 121.53M  26.2MB/s    in 5.7s
#
# 2022-01-27 13:09:55 (21.5 MB/s) - ‘driver_drowsiness_detection_modified.zip’ saved [127436131/127436131]

# %%
data = np.load('driver_drowsiness_detection/dataset_compressed.npz', allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']

X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img
    
print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {0, 1}

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161,)
# (291, 32, 32, 3)
# (291,)
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_closed = np.where(Y==0)
img_closed = X[idx_closed[0][0]]
plt.imshow(img_closed)
plt.title('Image of Closed Eye representing Driver is sleeping')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_open = np.where(Y==1)
img_open = X[idx_open[0][0]]
plt.imshow(img_open)
plt.title('Image of Open Eye representing Driver is not sleeping')
plt.axis('off')
plt.show()

# %%
unique_train, count = np.unique(Y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_train, count).set_title("Número de imagens de treinamento por categoria")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(Y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(unique_test, count_test).set_title("Número de imagens de teste por categoria")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam(0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 8, 8, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv5 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_4 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv6 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv7 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_6 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  fc1 (Dense)                 (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  fc3 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 227,554
# Trainable params: 226,786
# Non-trainable params: 768
# _________________________________________________________________

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 11s 134ms/step - loss: 1.5261 - accuracy: 0.4918 - val_loss: 0.7041 - val_accuracy: 0.4777
# Epoch 2/200
# 10/10 [==============================] - 1s 82ms/step - loss: 1.2184 - accuracy: 0.5512 - val_loss: 0.7030 - val_accuracy: 0.4742
# Epoch 3/200
# 10/10 [==============================] - 1s 81ms/step - loss: 1.0603 - accuracy: 0.5607 - val_loss: 0.6925 - val_accuracy: 0.5223
# Epoch 4/200
# 10/10 [==============================] - 1s 81ms/step - loss: 1.0192 - accuracy: 0.6003 - val_loss: 0.6757 - val_accuracy: 0.5670
# Epoch 5/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.9866 - accuracy: 0.5943 - val_loss: 0.6588 - val_accuracy: 0.6701
# Epoch 6/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.8564 - accuracy: 0.6245 - val_loss: 0.6465 - val_accuracy: 0.7423
# Epoch 7/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.9019 - accuracy: 0.6012 - val_loss: 0.6370 - val_accuracy: 0.7354
# Epoch 8/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.8225 - accuracy: 0.6382 - val_loss: 0.6275 - val_accuracy: 0.7216
# Epoch 9/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.7706 - accuracy: 0.6520 - val_loss: 0.6150 - val_accuracy: 0.7216
# Epoch 10/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.7637 - accuracy: 0.6357 - val_loss: 0.5990 - val_accuracy: 0.7285
# Epoch 11/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.7204 - accuracy: 0.6649 - val_loss: 0.5823 - val_accuracy: 0.7216
# Epoch 12/200
# 10/10 [==============================] - 1s 92ms/step - loss: 0.6632 - accuracy: 0.6985 - val_loss: 0.5690 - val_accuracy: 0.7423
# Epoch 13/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.6580 - accuracy: 0.6977 - val_loss: 0.5535 - val_accuracy: 0.7423
# Epoch 14/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.6294 - accuracy: 0.7175 - val_loss: 0.5372 - val_accuracy: 0.7526
# Epoch 15/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.6438 - accuracy: 0.7054 - val_loss: 0.5185 - val_accuracy: 0.7629
# Epoch 16/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.6375 - accuracy: 0.7209 - val_loss: 0.5012 - val_accuracy: 0.7629
# Epoch 17/200
# 10/10 [==============================] - 1s 91ms/step - loss: 0.5582 - accuracy: 0.7304 - val_loss: 0.4825 - val_accuracy: 0.7629
# Epoch 18/200
# 10/10 [==============================] - 1s 91ms/step - loss: 0.5830 - accuracy: 0.7261 - val_loss: 0.4649 - val_accuracy: 0.7732
# Epoch 19/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.5355 - accuracy: 0.7588 - val_loss: 0.4483 - val_accuracy: 0.7835
# Epoch 20/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.5363 - accuracy: 0.7649 - val_loss: 0.4353 - val_accuracy: 0.7973
# Epoch 21/200
# 10/10 [==============================] - 2s 168ms/step - loss: 0.5036 - accuracy: 0.7821 - val_loss: 0.4200 - val_accuracy: 0.8041
# Epoch 22/200
# 10/10 [==============================] - 2s 167ms/step - loss: 0.4549 - accuracy: 0.7907 - val_loss: 0.3974 - val_accuracy: 0.8110
# Epoch 23/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4545 - accuracy: 0.8165 - val_loss: 0.3733 - val_accuracy: 0.8488
# Epoch 24/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.4684 - accuracy: 0.7907 - val_loss: 0.3558 - val_accuracy: 0.8660
# Epoch 25/200
# 10/10 [==============================] - 1s 87ms/step - loss: 0.4986 - accuracy: 0.8140 - val_loss: 0.3414 - val_accuracy: 0.8625
# Epoch 26/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.4546 - accuracy: 0.8045 - val_loss: 0.3270 - val_accuracy: 0.8660
# Epoch 27/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3961 - accuracy: 0.8415 - val_loss: 0.3129 - val_accuracy: 0.8832
# Epoch 28/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.4198 - accuracy: 0.8200 - val_loss: 0.3004 - val_accuracy: 0.8832
# Epoch 29/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3890 - accuracy: 0.8389 - val_loss: 0.2848 - val_accuracy: 0.8900
# Epoch 30/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3908 - accuracy: 0.8226 - val_loss: 0.2651 - val_accuracy: 0.8969
# Epoch 31/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3415 - accuracy: 0.8622 - val_loss: 0.2458 - val_accuracy: 0.9003
# Epoch 32/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3601 - accuracy: 0.8562 - val_loss: 0.2389 - val_accuracy: 0.9003
# Epoch 33/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.3885 - accuracy: 0.8527 - val_loss: 0.2352 - val_accuracy: 0.9003
# Epoch 34/200
# 10/10 [==============================] - 1s 89ms/step - loss: 0.3136 - accuracy: 0.8734 - val_loss: 0.2272 - val_accuracy: 0.9107
# Epoch 35/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3063 - accuracy: 0.8682 - val_loss: 0.2218 - val_accuracy: 0.9107
# Epoch 36/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.3346 - accuracy: 0.8648 - val_loss: 0.2143 - val_accuracy: 0.9141
# Epoch 37/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.3305 - accuracy: 0.8708 - val_loss: 0.2114 - val_accuracy: 0.9244
# Epoch 38/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2991 - accuracy: 0.8846 - val_loss: 0.2066 - val_accuracy: 0.9175
# Epoch 39/200
# 10/10 [==============================] - 1s 114ms/step - loss: 0.2923 - accuracy: 0.8820 - val_loss: 0.1944 - val_accuracy: 0.9313
# Epoch 40/200
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2814 - accuracy: 0.9018 - val_loss: 0.1827 - val_accuracy: 0.9347
# Epoch 41/200
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2502 - accuracy: 0.9009 - val_loss: 0.1721 - val_accuracy: 0.9347
# Epoch 42/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2697 - accuracy: 0.8949 - val_loss: 0.1649 - val_accuracy: 0.9313
# Epoch 43/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2479 - accuracy: 0.9009 - val_loss: 0.1575 - val_accuracy: 0.9278
# Epoch 44/200
# 10/10 [==============================] - 1s 87ms/step - loss: 0.2574 - accuracy: 0.9121 - val_loss: 0.1511 - val_accuracy: 0.9313
# Epoch 45/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.2485 - accuracy: 0.8992 - val_loss: 0.1473 - val_accuracy: 0.9313
# Epoch 46/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.2098 - accuracy: 0.9173 - val_loss: 0.1422 - val_accuracy: 0.9381
# Epoch 47/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2643 - accuracy: 0.9018 - val_loss: 0.1392 - val_accuracy: 0.9381
# Epoch 48/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2272 - accuracy: 0.9165 - val_loss: 0.1332 - val_accuracy: 0.9416
# Epoch 49/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.2426 - accuracy: 0.9070 - val_loss: 0.1263 - val_accuracy: 0.9416
# Epoch 50/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2330 - accuracy: 0.9113 - val_loss: 0.1243 - val_accuracy: 0.9519
# Epoch 51/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2147 - accuracy: 0.9104 - val_loss: 0.1250 - val_accuracy: 0.9553
# Epoch 52/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.2026 - accuracy: 0.9130 - val_loss: 0.1254 - val_accuracy: 0.9553
# Epoch 53/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1932 - accuracy: 0.9302 - val_loss: 0.1281 - val_accuracy: 0.9519
# Epoch 54/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1762 - accuracy: 0.9276 - val_loss: 0.1239 - val_accuracy: 0.9553
# Epoch 55/200
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2213 - accuracy: 0.9233 - val_loss: 0.1226 - val_accuracy: 0.9553
# Epoch 56/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1720 - accuracy: 0.9285 - val_loss: 0.1185 - val_accuracy: 0.9553
# Epoch 57/200
# 10/10 [==============================] - 1s 89ms/step - loss: 0.1738 - accuracy: 0.9388 - val_loss: 0.1037 - val_accuracy: 0.9588
# Epoch 58/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.1757 - accuracy: 0.9242 - val_loss: 0.0989 - val_accuracy: 0.9588
# Epoch 59/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1770 - accuracy: 0.9337 - val_loss: 0.1111 - val_accuracy: 0.9553
# Epoch 60/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1856 - accuracy: 0.9345 - val_loss: 0.1190 - val_accuracy: 0.9485
# Epoch 61/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1827 - accuracy: 0.9440 - val_loss: 0.1072 - val_accuracy: 0.9588
# Epoch 62/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.1481 - accuracy: 0.9406 - val_loss: 0.1132 - val_accuracy: 0.9519
# Epoch 63/200
# 10/10 [==============================] - 1s 94ms/step - loss: 0.1721 - accuracy: 0.9371 - val_loss: 0.1021 - val_accuracy: 0.9622
# Epoch 64/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.1461 - accuracy: 0.9449 - val_loss: 0.0953 - val_accuracy: 0.9622
# Epoch 65/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1446 - accuracy: 0.9466 - val_loss: 0.0968 - val_accuracy: 0.9588
# Epoch 66/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1423 - accuracy: 0.9449 - val_loss: 0.1152 - val_accuracy: 0.9416
# Epoch 67/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1518 - accuracy: 0.9414 - val_loss: 0.0963 - val_accuracy: 0.9656
# Epoch 68/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1621 - accuracy: 0.9388 - val_loss: 0.1014 - val_accuracy: 0.9519
# Epoch 69/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.1234 - accuracy: 0.9552 - val_loss: 0.1059 - val_accuracy: 0.9519
# Epoch 70/200
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1334 - accuracy: 0.9475 - val_loss: 0.1128 - val_accuracy: 0.9553
# Epoch 71/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.1357 - accuracy: 0.9475 - val_loss: 0.1049 - val_accuracy: 0.9485
# Epoch 72/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1438 - accuracy: 0.9466 - val_loss: 0.1014 - val_accuracy: 0.9553
# Epoch 73/200
# 10/10 [==============================] - 1s 79ms/step - loss: 0.1264 - accuracy: 0.9492 - val_loss: 0.1032 - val_accuracy: 0.9450
# Epoch 74/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1394 - accuracy: 0.9406 - val_loss: 0.1041 - val_accuracy: 0.9553
# Epoch 75/200
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1130 - accuracy: 0.9569 - val_loss: 0.0993 - val_accuracy: 0.9588
# Epoch 76/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.1056 - accuracy: 0.9604 - val_loss: 0.0929 - val_accuracy: 0.9622
# Epoch 77/200
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1289 - accuracy: 0.9535 - val_loss: 0.0871 - val_accuracy: 0.9656
# Epoch 78/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.1282 - accuracy: 0.9526 - val_loss: 0.0852 - val_accuracy: 0.9691
# Epoch 79/200
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0968 - accuracy: 0.9638 - val_loss: 0.0847 - val_accuracy: 0.9725
# Epoch 80/200
# 10/10 [==============================] - 1s 79ms/step - loss: 0.1019 - accuracy: 0.9638 - val_loss: 0.0873 - val_accuracy: 0.9759
# Epoch 81/200
# 10/10 [==============================] - 1s 90ms/step - loss: 0.1058 - accuracy: 0.9621 - val_loss: 0.0892 - val_accuracy: 0.9691
# Epoch 82/200
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1327 - accuracy: 0.9500 - val_loss: 0.0963 - val_accuracy: 0.9691
# Epoch 83/200
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1069 - accuracy: 0.9612 - val_loss: 0.0918 - val_accuracy: 0.9691
# Epoch 84/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.1401 - accuracy: 0.9561 - val_loss: 0.0837 - val_accuracy: 0.9725
# Epoch 85/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.1038 - accuracy: 0.9621 - val_loss: 0.0832 - val_accuracy: 0.9759
# Epoch 86/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0897 - accuracy: 0.9630 - val_loss: 0.0861 - val_accuracy: 0.9794
# Epoch 87/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0892 - accuracy: 0.9690 - val_loss: 0.0906 - val_accuracy: 0.9725
# Epoch 88/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0953 - accuracy: 0.9673 - val_loss: 0.0964 - val_accuracy: 0.9725
# Epoch 89/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0916 - accuracy: 0.9664 - val_loss: 0.1014 - val_accuracy: 0.9622
# Epoch 90/200
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0773 - accuracy: 0.9750 - val_loss: 0.0991 - val_accuracy: 0.9725
# Epoch 91/200
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0874 - accuracy: 0.9707 - val_loss: 0.1009 - val_accuracy: 0.9794
# Epoch 92/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0
200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0380 - accuracy: 0.9871 - val_loss: 0.0519 - val_accuracy: 0.9759
# Epoch 189/200
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0208 - accuracy: 0.9922 - val_loss: 0.0567 - val_accuracy: 0.9725
# Epoch 190/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.0539 - val_accuracy: 0.9759
# Epoch 191/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0394 - accuracy: 0.9836 - val_loss: 0.0541 - val_accuracy: 0.9794
# Epoch 192/200
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0410 - accuracy: 0.9888 - val_loss: 0.0538 - val_accuracy: 0.9794
# Epoch 193/200
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0271 - accuracy: 0.9922 - val_loss: 0.0527 - val_accuracy: 0.9828
# Epoch 194/200
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0278 - accuracy: 0.9879 - val_loss: 0.0536 - val_accuracy: 0.9794
# Epoch 195/200
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0393 - accuracy: 0.9819 - val_loss: 0.0550 - val_accuracy: 0.9794
# Epoch 196/200
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0292 - accuracy: 0.9897 - val_loss: 0.0629 - val_accuracy: 0.9828
# Epoch 197/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0356 - accuracy: 0.9905 - val_loss: 0.0618 - val_accuracy: 0.9759
# Epoch 198/200
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0247 - accuracy: 0.9897 - val_loss: 0.0584 - val_accuracy: 0.9828
# Epoch 199/200
# 10/10 [==============================] - 1s 86ms/step - loss: 0.0265 - accuracy: 0.9897 - val_loss: 0.0864 - val_accuracy: 0.9691
# Epoch 200/200
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.0815 - val_accuracy: 0.9725

# %% [markdown]
# ##Loss Values and Accuracy against Number of Epochs for Train Set and Test Set

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0815 - accuracy: 0.9725
# Test Set Accuracy: 0.9725086092948914
# Test Set Loss: 0.08153918385505676

# %% [markdown]
# #Classification Report

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       156
#            1       0.94      1.00      0.97       135
#
#     accuracy                           0.97       291
#    macro avg       0.97      0.97      0.97       291
# weighted avg       0.97      0.97      0.97       291

# %% [markdown]
# #Confusion Matrix

# %%
matrix = confusion_matrix(Y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')

# %%
model.save('Driver_Drowsiness_Detection.h5')

# %%
labels = ['Closed', 'Open']
img_closed1 = cv2.imread('driver_drowsiness_detection/closed_eye.jpg')
img_closed2 = cv2.imread('driver_drowsiness_detection/closed_eye2.jpg')
img_open1 = cv2.imread('driver_drowsiness_detection/open_eye.jpg')
img_open2 = cv2.imread('driver_drowsiness_detection/open_eye2.jpg')

img_closed1 = cv2.resize(img_closed1, (32, 32))
img_closed2 = cv2.resize(img_closed2, (32, 32))
img_open1 = cv2.resize(img_open1, (32, 32))
img_open2 = cv2.resize(img_open2, (32, 32))

img_closed1 = np.array(img_closed1)
img_closed2 = np.array(img_closed2)
img_open1 = np.array(img_open1)
img_open2 = np.array(img_open2)

img_closed1 = np.expand_dims(img_closed1, axis=0)
img_closed2 = np.expand_dims(img_closed2, axis=0)
img_open1 = np.expand_dims(img_open1, axis=0)
img_open2 = np.expand_dims(img_open2, axis=0)

# %%
ypred_closed1 = model.predict(img_closed1)
ypred_closed2 = model.predict(img_closed2)
ypred_open1 = model.predict(img_open1)
ypred_open2 = model.predict(img_open2)

# %%
figure = plt.figure(figsize=(2, 2))
img_closed1 = np.squeeze(img_closed1, axis=0)
plt.imshow(img_closed1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_closed2 = np.squeeze(img_closed2, axis=0)
plt.imshow(img_closed2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed2[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open1 = np.squeeze(img_open1, axis=0)
plt.imshow(img_open1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open2 = np.squeeze(img_open2, axis=0)
plt.imshow(img_open2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open2[0], axis=0)]}')
plt.show()

# %% [markdown]
# ##Pipeline de detecção de rosto, alinhamento, detecção de olhos, definição de rdi e input para o modelo.

# %%
def full_face_detection_pipeline(input_image_path):
    face_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_eye.xml')
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor('driver_drowsiness_detection/shape_predictor_68_face_landmarks.dat')
    fa = FaceAligner(predictor, desiredFaceWidth=256)
    test_image = cv2.imread(input_image_path)
    test_image = imutils.resize(test_image, width=800)
    test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    rects = detector(test_image_gray, 2)
    for rect in rects:
        (x, y, w, h) = rect_to_bb(rect)
        faceOrig = imutils.resize(test_image[y:y+h, x:x+w], width=256)
        faceAligned = fa.align(test_image, test_image_gray, rect)
        faceAligned_gray = cv2.cvtColor(faceAligned, cv2.COLOR_BGR2GRAY)
        plt.imshow(faceAligned_gray)
        plt.axis('off')
        plt.title('Aligned Face')
        plt.show()
        eyes = eye_cascade.detectMultiScale(faceAligned_gray, 1.1, 4)
        predictions = []
        for (ex, ey, ew, eh) in eyes:
            eye = faceAligned[ey:ey+eh, ex:ex+ew]
#             cv2.rectangle(test_image, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 8)
            eye = cv2.resize(eye, (32, 32))
            eye = np.array(eye)
            eye = np.expand_dims(eye, axis=0)
            ypred = model.predict(eye)
            ypred = np.argmax(ypred[0], axis=0)
            predictions.append(ypred)
        if all(i==0 for i in predictions):
            cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 0, 255), 8)
            cv2.putText(test_image, 'Sleeping', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 3)
        else:
            cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 8)
            cv2.putText(test_image, 'Not Sleeping', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)
    output_path = 'driver_drowsiness_detection/test_image_prediction.jpg'
    cv2.imwrite(output_path, test_image) 
    return output_path

# %%
figure = plt.figure(figsize=(5, 5))
predicted_image = cv2.imread(full_face_detection_pipeline('driver_drowsiness_detection/active_person.jpg'))
predicted_image = cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB)
plt.imshow(predicted_image)
plt.axis('off')
plt.show()

# %%
figure = plt.figure(figsize=(5, 5))
predicted_image = cv2.imread(full_face_detection_pipeline('driver_drowsiness_detection/drowsy_person.jpg'))
predicted_image = cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB)
plt.imshow(predicted_image)
plt.axis('off')
plt.show()

# %%
figure = plt.figure(figsize=(5, 5))
predicted_image = cv2.imread(full_face_detection_pipeline('driver_drowsiness_detection/sleepy-driver.jpg'))
predicted_image = cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB)
plt.imshow(predicted_image)
plt.axis('off')
plt.show()
